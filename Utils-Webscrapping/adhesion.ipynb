# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_2001 = pd.read_csv('../Raw/Temporadas2001.csv')
df_2002 = pd.read_csv('../Raw/Temporadas2002.csv')
df_2003 = pd.read_csv('../Raw/Temporadas2003.csv')
df_2004 = pd.read_csv('../Raw/Temporadas2004.csv')
df_2005 = pd.read_csv('../Raw/Temporadas2005.csv')
df_2006 = pd.read_csv('../Raw/Temporadas2006.csv')
df_2007 = pd.read_csv('../Raw/Temporadas2007.csv')
df_2008 = pd.read_csv('../Raw/Temporadas2008.csv')
df_2009 = pd.read_csv('../Raw/Temporadas2009.csv')
df_2010 = pd.read_csv('../Raw/Temporadas20010.csv')
df_2011 = pd.read_csv('../Raw/Temporadas20011.csv')
df_2012 = pd.read_csv('../Raw/Temporadas20012.csv')
df_2013 = pd.read_csv('../Raw/Temporadas20013.csv')
df_2014 = pd.read_csv('../Raw/Temporadas20014.csv')
df_2015 = pd.read_csv('../Raw/Temporadas20015.csv')
df_2016 = pd.read_csv('../Raw/Temporadas20016.csv')
df_2017 = pd.read_csv('../Raw/Temporadas20017.csv')
df_2018 = pd.read_csv('../Raw/Temporadas20018.csv')
df_2019 = pd.read_csv('../Raw/Temporadas20019.csv')
df_2020 = pd.read_csv('../Raw/Temporadas20020.csv')
df_2021 = pd.read_csv('../Raw/Temporadas20021.csv')

# %%
df_final = pd.concat([
 df_2001,
 df_2002,
 df_2003,
 df_2004,
 df_2005,
 df_2006,
 df_2007,
 df_2008,
 df_2009,
 df_2010,
 df_2011,
 df_2012,
 df_2013,
 df_2014,
 df_2015,
 df_2016,
 df_2017,
 df_2018,
 df_2019,
 df_2020,
 df_2021])

# %%
pd.set_option('display.max_rows', 20)
pd.set_option('display.max_columns', None)

# %%
df_final.reset_index(inplace=True, drop=True)
df_final['Fecha'] = pd.to_datetime(df_final['Fecha'], format = "%Y/%m/%d")
df_final.sort_values(by='Fecha', inplace=True)
df_final
# Out:
#       Temporada      Fecha  Jornada         Equipo Local   Equipo Visitante  \
# 0             1 2000-09-09        1            Barcelona             Málaga
# 1             1 2000-09-09        1  DeportivodeLaCoruña       AthleticClub
# 2             1 2000-09-09        1         RealSociedad  RacingdeSantander
# 3             1 2000-09-09        1           RealMadrid           Valencia
# 4             1 2000-09-09        1             Zaragoza           Espanyol
# ...         ...        ...      ...                  ...                ...
# 7975         21 2021-05-22       38              Osasuna       RealSociedad
# 7976         21 2021-05-22       38           RealMadrid         Villarreal
# 7977         21 2021-05-22       38           Valladolid   AtléticodeMadrid
# 7970         21 2021-05-23       38              Granada             Getafe
# 7979         21 2021-05-23       38              Sevilla             Alavés
#
# ...

# %%
df_final.to_csv("../Raw/DF_Completo.csv", index = False)
